# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

from helper import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_dev = pd.read_csv('data/train.csv')
df_dev.dtypes

df_test = pd.read_csv('data/test.csv')
df_test.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_dev = preprocess_raw_data(df_dev)
df_test = preprocess_raw_data(df_test)

# %%
df_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.6+ KB

# %%
df_dev.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    1.352413   29.758889
# std     257.353842    0.486592    0.836071    0.477990   13.002570
# min       1.000000    0.000000    1.000000    1.000000    0.420000
# 25%     223.500000    0.000000    2.000000    1.000000   22.000000
# 50%     446.000000    0.000000    3.000000    1.000000   30.000000
# 75%     668.500000    1.000000    3.000000    2.000000   35.000000
# max     891.000000    1.000000    3.000000    2.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
df_dev.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
corr1(df_dev)

# %%
corr2(df_dev)

# %%
df_train, df_val = partition_dev_data(df_dev)

# %%
run_pipeline(df_train, df_val)
# Out:
# /Users/nanddalal/blah/titanic/helper.py:81: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.model.fit(x, y)
# Pclass 0.08466436421845236
# Sex 0.2669876395725661
# Age 0.2623452975362166
# Fare 0.29879631408657525
# SibSp 0.046371618210057086
# Parch 0.040834766376132536
# {'n': 712, 'prev': 0.3946629213483146, 'acc': 0.9803370786516854, 'roc_auc': 0.9975105481748149, 'ap': 0.9957824908250377}
# {'n': 179, 'prev': 0.3407821229050279, 'acc': 0.8044692737430168, 'roc_auc': 0.8500277854959711, 'ap': 0.7928986294903188}
